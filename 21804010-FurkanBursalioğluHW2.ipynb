# %%
yol=float(input('Seçeceginiz yolu ifade eden sayıyı girin:'))
if yol > 3:
    print('Yanlış veya ondalıklı sayı girdiniz, tekrar deneyin.')
elif yol < 1:
    print('Yanlış sayı veya ondalıklı girdiniz, tekrar deneyin.')
    

    
    
if yol == 1:
    print('Seçtiginiz bu yol herhangi sıfırdan farklı iki kenarı verilmiş üçgenin hipotenüsünü hesaplar.')
    a=int(input('Birinci kenarı girin:'))
    b=int(input('İkinci kenarı girin:'))
    if a == 0:
        print('Sıfırdan farklı sayı giriniz.')
            
    if b == 0:
        print('Sıfırdan farklı sayı giriniz.')
   
    if a!=0 and b!=0:
        hip=(a**2+b**2)**0.5
        print('Hipotenüs',hip)
 
        
if yol == 2:
    print('1 den seçiceginiz sayıya kadar olan kısmı yazar')
    t=int(input('Sayıyı giriniz:'))
    i = 1
    if i < t:
        Sayı=(t) 
        while i <= Sayı:
            print(i)
            if i == (Sayı):
                break
            i += 1
    if i > t:
        Sayı=(t-1) 
        while i >= t:
            print(i)
            if i == (Sayı):
                break
            i -= 1    
    

    if yol == 3:
        print('Gireceginiz 6 tane numaranın aritmetik ortalamasını hesaplar.')
    
        x=int(input('Birinci sayıyı girin:'))
        y=int(input('İkinci sayıyı girin:'))
        z=int(input('Üçüncü sayıyı girin:'))
        t=int(input('Dördüncü sayıyı girin:'))
        v=int(input('Beşinci sayıyı girin:'))
        c=int(input('Altıncı sayıyı girin:'))
    
        ort=(x+y+z+t+v+c)/6
        print('Aritmetik ortalamanız:',ort)
else :
    print('Tam sayı giriniz.')
